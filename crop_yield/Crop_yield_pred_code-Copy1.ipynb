# %%
import numpy
import pandas as pd

# %%
data=pd.read_csv("crop_yield.csv")

# %%
data.describe()
# Out:
#           Crop_Year          Area    Production  Annual_Rainfall  \
# count  19689.000000  1.968900e+04  1.968900e+04     19689.000000
# mean    2009.127584  1.799266e+05  1.643594e+07      1437.755177
# std        6.498099  7.328287e+05  2.630568e+08       816.909589
# min     1997.000000  5.000000e-01  0.000000e+00       301.300000
# 25%     2004.000000  1.390000e+03  1.393000e+03       940.700000
# 50%     2010.000000  9.317000e+03  1.380400e+04      1247.600000
# 75%     2015.000000  7.511200e+04  1.227180e+05      1643.700000
# max     2020.000000  5.080810e+07  6.326000e+09      6552.700000
#
#          Fertilizer     Pesticide         Yield
# count  1.968900e+04  1.968900e+04  19689.000000
# mean   2.410331e+07  4.884835e+04     79.954009
# std    9.494600e+07  2.132874e+05    878.306193
# min    5.417000e+01  9.000000e-02      0.000000
# 25%    1.880146e+05  3.567000e+02      0.600000
# 50%    1.234957e+06  2.421900e+03      1.030000
# 75%    1.000385e+07  2.004170e+04      2.388889
# max    4.835407e+09  1.575051e+07  21105.000000

# %%
import matplotlib.pyplot as plt

yearly_yield = data.groupby('Crop_Year')['Yield'].mean().reset_index()

plt.figure(figsize=(10, 6))
plt.plot(yearly_yield['Crop_Year'], yearly_yield['Yield'], marker='o', linestyle='-')
plt.title('Development of Yield Over Years Across All States')
plt.xlabel('Year')
plt.ylabel('Mean Yield')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Scatter plot showing the relationship between rainfall and yield
plt.figure(figsize=(8, 6))
plt.scatter(data['Annual_Rainfall'], data['Yield'])
plt.title('Rainfall vs Yield')
plt.xlabel('Annual Rainfall')
plt.ylabel('Yield')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()


data['Crop_Year'] = scaler.fit_transform(data[['Crop_Year']])
data['Area'] = scaler.fit_transform(data[['Area']])
data['Production'] = scaler.fit_transform(data[['Production']])
data['Annual_Rainfall'] = scaler.fit_transform(data[['Annual_Rainfall']])
data['Fertilizer'] = scaler.fit_transform(data[['Fertilizer']])
data['Pesticide'] = scaler.fit_transform(data[['Pesticide']])
data['Yield'] = scaler.fit_transform(data[['Yield']])

# %%
data
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut  -1.866375  Whole Year               Assam -0.144802
# 1          Arhar/Tur  -1.866375  Kharif                   Assam -0.236473
# 2        Castor seed  -1.866375  Kharif                   Assam -0.244443
# 3           Coconut   -1.866375  Whole Year               Assam -0.218707
# 4       Cotton(lint)  -1.866375  Kharif                   Assam -0.243157
# ...              ...        ...          ...                ...       ...
# 19684  Small millets  -1.712480  Kharif                Nagaland -0.240071
# 19685          Wheat  -1.712480  Rabi                  Nagaland -0.244165
# 19686          Maize  -1.866375  Kharif       Jammu and Kashmir  0.178704
# 19687           Rice  -1.866375  Kharif       Jammu and Kashmir  0.130756
# 19688          Wheat  -1.866375  Rabi         Jammu and Kashmir  0.081082
#
#        Production  Annual_Rainfall  Fertilizer  Pesticide     Yield
# 0       -0.062267         0.751197   -0.179880  -0.121745 -0.090128
# 1       -0.062464         0.751197   -0.247217  -0.219385 -0.090225
# 2       -0.062482         0.751197   -0.253072  -0.227875 -0.090763
# 3        0.419954         0.751197   -0.234167  -0.200462  5.872928
# 4       -0.062479         0.751197   -0.252127  -0.226504 -0.090555
# ...           ...              ...         ...        ...       ...
# 19684   -0.062475         0.073749   -0.249707  -0.223593 -0.090465
# 19685   -0.062471         0.073749   -0.252829  -0.227672 -0.087619
# 19686   -0.060806        -0.099836    0.057755   0.222829 -0.089571
# 19687   -0.062461        -0.099836    0.022534   0.171758 -0.091015
# 19688   -0.060991        -0.099836   -0.013955   0.118849 -0.089598
#
# [19689 rows x 10 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
data['Crop'] = label_encoder.fit_transform(data['Crop'])
data['Season'] = label_encoder.fit_transform(data['Season'])
data['State'] = label_encoder.fit_transform(data['State'])

# %%
data
# Out:
#        Crop  Crop_Year  Season  State      Area  Production  Annual_Rainfall  \
# 0         0  -1.866375       4      2 -0.144802   -0.062267         0.751197
# 1         1  -1.866375       1      2 -0.236473   -0.062464         0.751197
# 2         8  -1.866375       1      2 -0.244443   -0.062482         0.751197
# 3         9  -1.866375       4      2 -0.218707    0.419954         0.751197
# 4        11  -1.866375       1      2 -0.243157   -0.062479         0.751197
# ...     ...        ...     ...    ...       ...         ...              ...
# 19684    44  -1.712480       1     19 -0.240071   -0.062475         0.073749
# 19685    53  -1.712480       2     19 -0.244165   -0.062471         0.073749
# 19686    24  -1.866375       1     10  0.178704   -0.060806        -0.099836
# 19687    40  -1.866375       1     10  0.130756   -0.062461        -0.099836
# 19688    53  -1.866375       2     10  0.081082   -0.060991        -0.099836
#
#        Fertilizer  Pesticide     Yield
# 0       -0.179880  -0.121745 -0.090128
# 1       -0.247217  -0.219385 -0.090225
# 2       -0.253072  -0.227875 -0.090763
# 3       -0.234167  -0.200462  5.872928
# 4       -0.252127  -0.226504 -0.090555
# ...           ...        ...       ...
# 19684   -0.249707  -0.223593 -0.090465
# 19685   -0.252829  -0.227672 -0.087619
# 19686    0.057755   0.222829 -0.089571
# 19687    0.022534   0.171758 -0.091015
# 19688   -0.013955   0.118849 -0.089598
#
# [19689 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

# %%
yearly_yield = data.groupby('Crop_Year')['Yield'].mean().reset_index()

plt.figure(figsize=(10, 6))
plt.plot(yearly_yield['Crop_Year'], yearly_yield['Yield'], marker='o', linestyle='-')
plt.title('Development of Yield Over Years Across All States')
plt.xlabel('Year')
plt.ylabel('Mean Yield')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
X=data.iloc[:,:9]
y=data.iloc[:,9]

# %%
X=X.drop(columns='Crop_Year')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
classifier=Sequential()
classifier.add(Dense(units=16, activation='relu'))
classifier.add(Dense(units=6, activation='relu'))
classifier.add(Dense(units=1, activation='linear'))

# %%
classifier.compile(optimizer='adam', loss='mean_squared_error')

# %%
classifier.fit(X_train,y_train,batch_size=32,epochs=150)
# Out:
# Epoch 1/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 3.6203
# Epoch 2/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6035
# Epoch 3/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5284
# Epoch 4/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5570
# Epoch 5/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4906
# Epoch 6/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5442
# Epoch 7/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4274
# Epoch 8/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4513
# Epoch 9/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4065
# Epoch 10/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.4100
# Epoch 11/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4184
# Epoch 12/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3762
# Epoch 13/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3121
# Epoch 14/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2636
# Epoch 15/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3623
# Epoch 16/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3158
# Epoch 17/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2950
# Epoch 18/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3064
# Epoch 19/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2649
# Epoch 20/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2656
# Epoch 21/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2629
# Epoch 22/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2374
# Epoch 23/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2081
# Epoch 24/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2518
# Epoch 25/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1637
# Epoch 26/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2071
# Epoch 27/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2198
# Epoch 28/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1903
# Epoch 29/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2325
# Epoch 30/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1605
# Epoch 31/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1659
# Epoch 32/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1509
# Epoch 33/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.3010
# Epoch 34/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1822
# Epoch 35/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1691
# Epoch 36/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2421
# Epoch 37/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1719
# Epoch 38/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1734
# Epoch 39/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1749
# Epoch 40/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2642
# Epoch 41/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1866
# Epoch 42/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2539
# Epoch 43/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1355
# Epoch 44/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1616
# Epoch 45/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1410
# Epoch 46/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1635
# Epoch 47/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1332
# Epoch 48/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1486
# Epoch 49/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1662
# Epoch 50/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1764
# Epoch 51/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1511
# Epoch 52/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1917
# Epoch 53/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1652
# Epoch 54/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1553
# Epoch 55/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1635
# Epoch 56/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1396
# Epoch 57/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1424
# Epoch 58/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1469
# Epoch 59/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1232
# Epoch 60/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1754
# Epoch 61/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1403
# Epoch 62/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1467
# Epoch 63/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2002
# Epoch 64/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1297
# Epoch 65/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1106
# Epoch 66/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1700
# Epoch 67/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1071
# Epoch 68/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1605
# Epoch 69/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2113
# Epoch 70/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1084
# Epoch 71/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0728
# Epoch 72/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1231
# Epoch 73/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1128
# Epoch 74/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1093
# Epoch 75/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1155
# Epoch 76/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0888
# Epoch 77/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0922
# Epoch 78/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0650
# Epoch 79/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0671
# Epoch 80/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0862
# Epoch 81/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0713
# Epoch 82/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0624
# Epoch 83/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0801
# Epoch 84/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0574
# Epoch 85/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1093
# Epoch 86/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0505
# Epoch 87/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0474
# Epoch 88/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0515
# Epoch 89/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0671
# Epoch 90/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0391
# Epoch 91/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0605
# Epoch 92/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0421
# Epoch 93/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0520
# Epoch 94/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0454
# Epoch 95/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0295
# Epoch 96/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0659
# Epoch 97/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0376
# Epoch 98/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0609
# Epoch 99/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0774
# Epoch 100/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0309
# Epoch 101/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0870
# Epoch 102/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0352
# Epoch 103/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0670
# Epoch 104/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0403
# Epoch 105/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0511
# Epoch 106/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0458
# Epoch 107/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0612
# Epoch 108/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0266
# Epoch 109/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0518
# Epoch 110/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0487
# Epoch 111/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0519
# Epoch 112/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0325
# Epoch 113/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0305
# Epoch 114/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0697
# Epoch 115/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0238
# Epoch 116/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0383
# Epoch 117/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0389
# Epoch 118/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0426
# Epoch 119/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0403
# Epoch 120/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0338
# Epoch 121/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0431
# Epoch 122/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0331
# Epoch 123/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0416
# Epoch 124/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0357
# Epoch 125/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0314
# Epoch 126/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0884
# Epoch 127/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0251
# Epoch 128/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0510
# Epoch 129/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0841
# Epoch 130/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0271
# Epoch 131/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0550
# Epoch 132/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0309
# Epoch 133/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0215
# Epoch 134/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0298
# Epoch 135/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0460
# Epoch 136/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0318
# Epoch 137/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0213
# Epoch 138/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0394
# Epoch 139/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0300
# Epoch 140/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0336
# Epoch 141/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0269
# Epoch 142/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0287
# Epoch 143/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0822
# Epoch 144/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0871
# Epoch 145/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0446
# Epoch 146/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0373
# Epoch 147/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0638
# Epoch 148/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0217
# Epoch 149/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0557
# Epoch 150/150
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0375

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
y_pred = classifier.predict(X_test)
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.04252562935885836

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 0.11792377396402602

# %%
classifier.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_13 (Dense)                     │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 6)                   │             102 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 1)                   │               7 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 761 (2.98 KB)
#  Trainable params: 253 (1012.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 508 (1.99 KB)

# %%
import numpy as np

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.scatter(y_test.values, y_pred, color='blue', label='Actual vs Predicted')

max_val = np.max([np.max(y_test), np.max(y_pred)])

plt.plot([0, max_val], [0, max_val], color='red', linestyle='--', label='Ideal Line')

plt.title('Actual vs Predicted Yield')
plt.xlabel('Actual Yield')
plt.ylabel('Predicted Yield')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r=r2_score(y_test,y_pred)

# %%
print(r)
# Out:
# 0.8826810885727058
